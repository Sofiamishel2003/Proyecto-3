# %% [markdown]
# # Proyecto 3
# ### Integrantes
# - Nicolle Gordillo
# - Fabiola Contreras
# - Sofía Velasquez
# - María José Villafuerte

# %% [markdown]
# ## Analisis Exploratorio
#
# ### Descripción del conjunto de datos

# %%
# IMPORTACIONES
import pandas as pd
import numpy as np
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# CARGA DE DATASETS
divorcios_df = pd.read_csv("divorcios_limpio.csv")
matrimonios_df = pd.read_csv("matrimonios_limpio.csv")
# Out:
# C:\Users\Fabi\AppData\Local\Temp\ipykernel_6788\3213548938.py:2: DtypeWarning: Columns (15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   divorcios_df = pd.read_csv("divorcios_limpio.csv")
# C:\Users\Fabi\AppData\Local\Temp\ipykernel_6788\3213548938.py:3: DtypeWarning: Columns (16,17,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   matrimonios_df = pd.read_csv("matrimonios_limpio.csv")

# %%
# Reemplazar datos ignorados
edad_columns = ["Edad del Hombre", "Edad de la Mujer"]
divorcios_df[edad_columns] = divorcios_df[edad_columns].replace(999, np.nan)
matrimonios_df[edad_columns] = matrimonios_df[edad_columns].replace(999, np.nan)

matrimonios_df["Numero de Nupcias del Hombre"] = matrimonios_df["Numero de Nupcias del Hombre"].replace(9, np.nan)
matrimonios_df["Numero de Nupcias de la Mujer"] = matrimonios_df["Numero de Nupcias de la Mujer"].replace(9, np.nan)

# Reemplazar "IGNORADO" y "NEOG" por NaN en las columnas de ocupación
ocupacion_columns = ['Ocupacion del Hombre', 'Ocupacion de la Mujer']
divorcios_df[ocupacion_columns] = divorcios_df[ocupacion_columns].replace(["IGNORADO", "NEOG"], np.nan)
matrimonios_df[ocupacion_columns] = matrimonios_df[ocupacion_columns].replace(["IGNORADO", "NEOG"], np.nan)

# Quitar guiones en municipios
matrimonios_df["Municipio de Ocurrencia"] = matrimonios_df["Municipio de Ocurrencia"].str.replace("-", "", regex=True)

# %%
# Resumen general: número de variables y observaciones por dataset
divorcios_shape = divorcios_df.shape
matrimonios_shape = matrimonios_df.shape

# Tipos de variables
divorcios_types = divorcios_df.dtypes
matrimonios_types = matrimonios_df.dtypes

(divorcios_shape, divorcios_types, matrimonios_shape, matrimonios_types)
# Out:
# ((76669, 19),
#  Departamento de Registro             float64
#  Municipio de Registro                  int64
#  Mes de Registro                      float64
#  Ano de Registro                      float64
#  Dia de la Ocurrencia                 float64
#  Mes de la Ocurrencia                 float64
#  Ano Ocurrencia                       float64
#  Departamento de Ocurrencia           float64
#  Municipio de Ocurrencia                int64
#  Edad del Hombre                      float64
#  Edad de la Mujer                     float64
#  Nacionalidad del Hombre              float64
#  Nacionalidad de la Mujer             float64
#  Escolaridad del Hombre               float64
#  Escolaridad de la Mujer              float64
#  Ocupacion del Hombre                  object
#  Ocupacion de la Mujer                 object
#  Pueblo de Pertenencia del Hombre     float64
#  Pueblo de Pertenencia de la Mujer    float64
#  dtype: object,
#  (832242, 23),
#  Departamento de Registro             float64
#  Municipio de Registro                  int64
#  Mes de Registro                      float64
#  Ano de Registro                      float64
#  Ano Ocurrencia                       float64
#  Clase de Union                       float64
#  Numero de Nupcias del Hombre         float64
#  Numero de Nupcias de la Mujer        float64
#  Edad del Hombre                      float64
#  Edad de la Mujer                     float64
#  Pueblo de Pertenencia del Hombre     float64
#  Pueblo de Pertenencia de la Mujer    float64
#  Nacionalidad del Hombre              float64
#  Nacionalidad de la Mujer             float64
#  Escolaridad del Hombre               float64
#  Escolaridad de la Mujer              float64
#  Ocupacion del Hombre                  object
#  Ocupacion de la Mujer                 object
#  Departamento de Ocurrencia           float64
#  Municipio de Ocurrencia               object
#  Dia de la Ocurrencia                 float64
#  Mes de la Ocurrencia                 float64
#  Area Geografica de la Ocurrencia     float64
#  dtype: object)

# %% [markdown]
# Estadísticas básicas de las variables numéricas

# %%
# Dataset divorcios
matrimonios_df.describe() 
divorcios_df.describe()
# Out:
#        Departamento de Registro  Municipio de Registro  Mes de Registro  \
# count              76669.000000           76669.000000     76669.000000
# mean                   7.790137             783.952380         6.553874
# std                    6.978000             698.461718         3.404897
# min                    1.000000             101.000000         1.000000
# 25%                    1.000000             101.000000         4.000000
# 50%                    6.000000             601.000000         7.000000
# 75%                   13.000000            1301.000000        10.000000
# max                   22.000000            2217.000000        12.000000
#
#        Ano de Registro  Dia de la Ocurrencia  Mes de la Ocurrencia  \
# count     76669.000000          76669.000000          76669.000000
# mean       2018.880251             15.750603              6.305560
# std           3.224580              8.678669              3.305056
# min        2013.000000              1.000000              1.000000
# 25%        2016.000000              8.000000              3.000000
# 50%        2019.000000             16.000000              6.000000
# 75%        2022.000000             23.000000              9.000000
# max        2024.000000             31.000000             12.000000
#
#        Ano Ocurrencia  Departamento de Ocurrencia  Municipio de Ocurrencia  \
# count    65552.000000                76669.000000             76669.000000
# mean      2019.555223                    8.025330               808.115627
# std          2.614229                    7.016503               702.143049
# min       2015.000000                    1.000000               101.000000
# 25%       2017.000000                    1.000000               103.000000
# 50%       2020.000000                    6.000000               614.000000
# 75%       2022.000000                   13.000000              1314.000000
# max       2023.000000                   22.000000              2217.000000
#
#        Edad del Hombre  Edad de la Mujer  Nacionalidad del Hombre  \
# count     42096.000000      42148.000000             76669.000000
# mean         36.349012         33.192488               360.465703
# std           9.955368          9.107861               603.601280
# min          17.000000         15.000000                10.000000
# 25%          29.000000         27.000000               320.000000
# 50%          34.000000         31.000000               320.000000
# 75%          41.000000         38.000000               320.000000
# max          98.000000         81.000000              9999.000000
#
#        Nacionalidad de la Mujer  Escolaridad del Hombre  \
# count              76669.000000            76669.000000
# mean                 361.807262                5.570935
# std                  611.713141                3.173225
# min                   32.000000                0.000000
# 25%                  320.000000                3.000000
# 50%                  320.000000                4.000000
# 75%                  320.000000                9.000000
# max                 9999.000000                9.000000
#
#        Escolaridad de la Mujer  Pueblo de Pertenencia del Hombre  \
# count             76669.000000                      76669.000000
# mean                  5.533853                          6.222985
# std                   3.177932                          2.835524
# min                   0.000000                          1.000000
# 25%                   3.000000                          4.000000
# 50%                   4.000000                          4.000000
# 75%                   9.000000                          9.000000
# max                   9.000000                          9.000000
#
#        Pueblo de Pertenencia de la Mujer
# count                       76669.000000
# mean                            6.249527
# std                             2.812197
# min                             1.000000
# 25%                             4.000000
# 50%                             5.000000
# 75%                             9.000000
# max                             9.000000

# %%
# Matrimonios
matrimonios_df.describe()
# Out:
#        Departamento de Registro  Municipio de Registro  Mes de Registro  \
# count             832242.000000          832242.000000    832242.000000
# mean                   9.579895             965.483121         6.470238
# std                    6.396578             640.256366         3.593166
# min                    1.000000             101.000000         1.000000
# 25%                    4.000000             401.000000         3.000000
# 50%                   10.000000            1003.000000         6.000000
# 75%                   14.000000            1418.000000        10.000000
# max                   22.000000            2217.000000        12.000000
#
#        Ano de Registro  Ano Ocurrencia  Clase de Union  \
# count    832242.000000   671996.000000   832242.000000
# mean       2018.069674     2019.041819        2.965339
# std           3.219232        2.609263        0.918205
# min        2013.000000     2015.000000        1.000000
# 25%        2015.000000     2017.000000        3.000000
# 50%        2018.000000     2019.000000        3.000000
# 75%        2021.000000     2021.000000        3.000000
# max        2024.000000     2023.000000        9.000000
#
#        Numero de Nupcias del Hombre  Numero de Nupcias de la Mujer  \
# count                 213899.000000                  213998.000000
# mean                       1.013619                       1.007958
# std                        0.118810                       0.090829
# min                        1.000000                       1.000000
# 25%                        1.000000                       1.000000
# 50%                        1.000000                       1.000000
# 75%                        1.000000                       1.000000
# max                        4.000000                       4.000000
#
#        Edad del Hombre  Edad de la Mujer  Pueblo de Pertenencia del Hombre  \
# count    832115.000000     832080.000000                     832242.000000
# mean         29.981531         27.013973                          3.266632
# std          11.388806          9.966577                          2.106755
# min          14.000000         12.000000                          1.000000
# 25%          23.000000         20.000000                          1.000000
# 50%          27.000000         24.000000                          4.000000
# 75%          33.000000         30.000000                          4.000000
# max          99.000000         99.000000                          9.000000
#
#        Pueblo de Pertenencia de la Mujer  Nacionalidad del Hombre  \
# count                      832242.000000            832242.000000
# mean                            3.443963               322.271840
# std                             2.287599                46.021786
# min                             1.000000                 8.000000
# 25%                             1.000000               320.000000
# 50%                             4.000000               320.000000
# 75%                             4.000000               320.000000
# max                             9.000000              9999.000000
#
#        Nacionalidad de la Mujer  Escolaridad del Hombre  \
# count             832242.000000            832242.00000
# mean                 321.967771                 3.05759
# std                   41.938488                 1.62841
# min                    8.000000                 1.00000
# 25%                  320.000000                 2.00000
# 50%                  320.000000                 3.00000
# 75%                  320.000000                 4.00000
# max                 9999.000000                 9.00000
#
#        Escolaridad de la Mujer  Departamento de Ocurrencia  \
# count            832242.000000               832242.000000
# mean                  3.117449                    9.589712
# std                   1.930229                    6.382463
# min                   1.000000                    1.000000
# 25%                   2.000000                    4.000000
# 50%                   3.000000                   10.000000
# 75%                   4.000000                   14.000000
# max                   9.000000                   22.000000
#
#        Dia de la Ocurrencia  Mes de la Ocurrencia  \
# count         832242.000000         832242.000000
# mean              16.052043              6.697891
# std                8.629011              3.599157
# min                1.000000              1.000000
# 25%                9.000000              3.000000
# 50%               16.000000              7.000000
# 75%               23.000000             10.000000
# max               31.000000             12.000000
#
#        Area Geografica de la Ocurrencia
# count                     380630.000000
# mean                           2.126033
# std                            2.625505
# min                            1.000000
# 25%                            1.000000
# 50%                            1.000000
# 75%                            1.000000
# max                           11.000000

# %% [markdown]
# Valores nulos

# %%
# Divorcios
missing_values = divorcios_df.isnull().sum()
missing_values = missing_values[missing_values > 0].sort_values(ascending=False)
print(missing_values)
plt.figure(figsize=(12,6))
sns.heatmap(divorcios_df.isnull(), cmap='viridis', cbar=False, yticklabels=False)
plt.show()
# Out:
# Edad del Hombre          34573
# Edad de la Mujer         34521
# Ano Ocurrencia           11117
# Ocupacion de la Mujer     8913
# Ocupacion del Hombre      6281
# dtype: int64

# %%
# Matrimonios
missing_values = matrimonios_df.isnull().sum()
missing_values = missing_values[missing_values > 0].sort_values(ascending=False)
print(missing_values)
plt.figure(figsize=(12,6))
sns.heatmap(matrimonios_df.isnull(), cmap='viridis', cbar=False, yticklabels=False)
plt.show()
# Out:
# Municipio de Ocurrencia             720896
# Numero de Nupcias del Hombre        618343
# Numero de Nupcias de la Mujer       618244
# Area Geografica de la Ocurrencia    451612
# Ano Ocurrencia                      160246
# Ocupacion de la Mujer               129437
# Ocupacion del Hombre                 37089
# Edad de la Mujer                       162
# Edad del Hombre                        127
# dtype: int64

# %% [markdown]
# ### Resumen de las variables

# %%
# Variables cuantitativas
matrimonios_cuantitativas = [
    "Mes de Registro",
    "Ano de Registro",
    "Ano Ocurrencia",
    "Numero de Nupcias del Hombre",
    "Numero de Nupcias de la Mujer",
    "Edad del Hombre",
    "Edad de la Mujer",
    "Dia de la Ocurrencia",
    "Mes de la Ocurrencia"
]

divorcios_cuantitativas = [
    "Mes de Registro",
    "Ano de Registro",
    "Dia de la Ocurrencia",
    "Mes de la Ocurrencia",
    "Ano Ocurrencia",
    "Edad del Hombre",
    "Edad de la Mujer"
]

# Variables categóricas
matrimonios_categoricas = [
    "Departamento de Registro",
    "Municipio de Registro",
    "Clase de Union",
    "Pueblo de Pertenencia del Hombre",
    "Pueblo de Pertenencia de la Mujer",
    "Nacionalidad del Hombre",
    "Nacionalidad de la Mujer",
    "Escolaridad del Hombre",
    "Escolaridad de la Mujer",
    "Ocupacion del Hombre",
    "Ocupacion de la Mujer",
    "Departamento de Ocurrencia",
    "Municipio de Ocurrencia",
    "Area Geografica de la Ocurrencia"
]

divorcios_categoricas = [
    "Departamento de Registro",
    "Municipio de Registro",
    "Departamento de Ocurrencia",
    "Municipio de Ocurrencia",
    "Nacionalidad del Hombre",
    "Nacionalidad de la Mujer",
    "Escolaridad del Hombre",
    "Escolaridad de la Mujer",
    "Ocupacion del Hombre",
    "Ocupacion de la Mujer",
    "Pueblo de Pertenencia del Hombre",
    "Pueblo de Pertenencia de la Mujer"
]

# %% [markdown]
# Resumenes númericos

# %%
# Variables numéricas y categóricas
div_numeric = divorcios_df[divorcios_cuantitativas]
div_cat = divorcios_df[divorcios_categoricas]

mat_numeric = matrimonios_df[matrimonios_cuantitativas]
mat_cat = matrimonios_df[matrimonios_categoricas]
# Descripción numérica
print("\n### Estadísticas descriptivas - divorcios_df")
print(div_numeric.describe())

print("\n### Estadísticas descriptivas - matrimonios_df")
print(mat_numeric.describe())
# Out:
# ### Estadísticas descriptivas - divorcios_df
#        Mes de Registro  Ano de Registro  Dia de la Ocurrencia  \
# count     76669.000000     76669.000000          76669.000000
# mean          6.553874      2018.880251             15.750603
# std           3.404897         3.224580              8.678669
# min           1.000000      2013.000000              1.000000
# 25%           4.000000      2016.000000              8.000000
# 50%           7.000000      2019.000000             16.000000
# 75%          10.000000      2022.000000             23.000000
# max          12.000000      2024.000000             31.000000
#
#        Mes de la Ocurrencia  Ano Ocurrencia  Edad del Hombre  Edad de la Mujer
# count          76669.000000    65552.000000     42096.000000      42148.000000
# mean               6.305560     2019.555223        36.349012         33.192488
# std                3.305056        2.614229         9.955368          9.107861
# min                1.000000     2015.000000        17.000000         15.000000
# 25%                3.000000     2017.000000        29.000000         27.000000
# 50%                6.000000     2020.000000        34.000000         31.000000
# 75%                9.000000     2022.000000        41.000000         38.000000
# max               12.000000     2023.000000        98.000000         81.000000
#
# ### Estadísticas descriptivas - matrimonios_df
#        Mes de Registro  Ano de Registro  Ano Ocurrencia  \
# count    832242.000000    832242.000000   671996.000000
# mean          6.470238      2018.069674     2019.041819
# std           3.593166         3.219232        2.609263
# min           1.000000      2013.000000     2015.000000
# 25%           3.000000      2015.000000     2017.000000
# 50%           6.000000      2018.000000     2019.000000
# 75%          10.000000      2021.000000     2021.000000
# max          12.000000      2024.000000     2023.000000
#
#        Numero de Nupcias del Hombre  Numero de Nupcias de la Mujer  \
# count                 213899.000000                  213998.000000
# mean                       1.013619                       1.007958
# std                        0.118810                       0.090829
# min                        1.000000                       1.000000
# 25%                        1.000000                       1.000000
# 50%                        1.000000                       1.000000
# 75%                        1.000000                       1.000000
# max                        4.000000                       4.000000
#
#        Edad del Hombre  Edad de la Mujer  Dia de la Ocurrencia  \
# count    832115.000000     832080.000000         832242.000000
# mean         29.981531         27.013973             16.052043
# std          11.388806          9.966577              8.629011
# min          14.000000         12.000000              1.000000
# 25%          23.000000         20.000000              9.000000
# 50%          27.000000         24.000000             16.000000
# 75%          33.000000         30.000000             23.000000
# max          99.000000         99.000000             31.000000
#
#        Mes de la Ocurrencia
# count         832242.000000
# mean               6.697891
# std                3.599157
# min                1.000000
# 25%                3.000000
# 50%                7.000000
# 75%               10.000000
# max               12.000000

# %% [markdown]
# Distribución de Variables Numéricas

# %%
def graficar_histogramas(df_numeric, titulo_dataset):
    cols = 3
    rows = (len(df_numeric.columns) + cols - 1) // cols
    fig, axes = plt.subplots(rows, cols, figsize=(20, 5 * rows))
    axes = axes.flatten()

    for i, col in enumerate(df_numeric.columns):
        df_numeric[col].hist(ax=axes[i], bins=50, edgecolor="black")
        axes[i].set_title(f"{col} ({titulo_dataset})")

    for j in range(i + 1, len(axes)):
        fig.delaxes(axes[j])

    plt.tight_layout()
    plt.show()

graficar_histogramas(div_numeric, "Divorcios")
graficar_histogramas(mat_numeric, "Matrimonios")

# %% [markdown]
# Análisis de Variables Categóricas

# %%
# TABLAS DE FRECUENCIA (CATEGÓRICAS)
print("\n### Frecuencias - Variables Categóricas divorcios_df")
for col in div_cat.columns:
    print(f"\n{col}:\n{div_cat[col].value_counts().head()}")

print("\n### Frecuencias - Variables Categóricas matrimonios_df")
for col in mat_cat.columns:
    print(f"\n{col}:\n{mat_cat[col].value_counts().head()}")
# Out:
# ### Frecuencias - Variables Categóricas divorcios_df
#
# Departamento de Registro:
# Departamento de Registro
# 1.0     29160
# 9.0      6546
# 5.0      3369
# 12.0     3071
# 22.0     2732
# Name: count, dtype: int64
#
# Municipio de Registro:
# Municipio de Registro
# 101     22280
# 901      3017
# 115      1851
# 2101     1812
# 1801     1516
# Name: count, dtype: int64
#
# Departamento de Ocurrencia:
# Departamento de Ocurrencia
# 1.0     27790
# 9.0      5933
# 5.0      3817
# 12.0     3472
# 22.0     3268
# Name: count, dtype: int64
#
# Municipio de Ocurrencia:
# Municipio de Ocurrencia
# 101    18396
# 108     2394
# 901     2214
# 115     2076
# 920     1325
# Name: count, dtype: int64
#
# Nacionalidad del Hombre:
# Nacionalidad del Hombre
# 320.0     75198
# 840.0       302
# 9999.0      298
# 222.0       166
# 720.0        82
# Name: count, dtype: int64
#
# Nacionalidad de la Mujer:
# Nacionalidad de la Mujer
# 320.0     75101
# 840.0       379
# 9999.0      306
# 222.0       264
# 340.0       108
# Name: count, dtype: int64
#
# Escolaridad del Hombre:
# Escolaridad del Hombre
# 9.0    33234
# 4.0    15539
# 1.0     9016
# 2.0     7668
# 3.0     6214
# Name: count, dtype: int64
#
# Escolaridad de la Mujer:
# Escolaridad de la Mujer
# 9.0    32856
# 4.0    16034
# 1.0     9371
# 2.0     7355
# 3.0     6155
# Name: count, dtype: int64
#
# Ocupacion del Hombre:
# Ocupacion del Hombre
# 97.0    14887
# 99.0    13550
# 92.0     8520
# 52.0     4291
# 98.0     3317
# Name: count, dtype: int64
#
# Ocupacion de la Mujer:
# Ocupacion de la Mujer
# 97.0    28758
# 99.0    14799
# 98.0     5849
# 23.0     3794
# 41.0     2717
# Name: count, dtype: int64
#
# Pueblo de Pertenencia del Hombre:
# Pueblo de Pertenencia del Hombre
# 9.0    37606
# 4.0    32369
# 1.0     6047
# 5.0      609
# 2.0       26
# Name: count, dtype: int64
#
# Pueblo de Pertenencia de la Mujer:
# Pueblo de Pertenencia de la Mujer
# 9.0    37726
# 4.0    32621
# 1.0     5594
# 5.0      687
# 2.0       25
# Name: count, dtype: int64
#
# ### Frecuencias - Variables Categóricas matrimonios_df
#
# Departamento de Registro:
# Departamento de Registro
# 1.0     168961
# 16.0     62216
# 13.0     58822
# 14.0     54336
# 12.0     53831
# Name: count, dtype: int64
#
# Municipio de Registro:
# Municipio de Registro
# 101     89524
# 115     13781
# 1601    12102
# 901     11712
# 1609    10459
# Name: count, dtype: int64
#
# Clase de Union:
# Clase de Union
# 3.0    752644
# 1.0     46163
# 2.0     19590
# 9.0     13845
# Name: count, dtype: int64
#
# Pueblo de Pertenencia del Hombre:
# Pueblo de Pertenencia del Hombre
# 4.0    457674
# 1.0    301958
# 9.0     56270
# 5.0     15383
# 3.0       715
# Name: count, dtype: int64
#
# Pueblo de Pertenencia de la Mujer:
# Pueblo de Pertenencia de la Mujer
# 4.0    444803
# 1.0    290933
# 9.0     79040
# 5.0     16263
# 3.0       985
# Name: count, dtype: int64
#
# Nacionalidad del Hombre:
# Nacionalidad del Hombre
# 320.0    824175
# 840.0      2240
# 222.0      1125
# 484.0      1035
# 723.0       521
# Name: count, dtype: int64
#
# Nacionalidad de la Mujer:
# Nacionalidad de la Mujer
# 320.0    823873
# 840.0      1980
# 222.0      1671
# 484.0       997
# 340.0       980
# Name: count, dtype: int64
#
# Escolaridad del Hombre:
# Escolaridad del Hombre
# 2.0    284089
# 4.0    236138
# 3.0    157582
# 1.0     86799
# 5.0     33579
# Name: count, dtype: int64
#
# Escolaridad de la Mujer:
# Escolaridad de la Mujer
# 2.0    258497
# 4.0    229490
# 1.0    131131
# 3.0    128910
# 9.0     54994
# Name: count, dtype: int64
#
# Ocupacion del Hombre:
# Ocupacion del Hombre
# 92.0    212724
# 97.0    166129
# 52.0     59399
# 61.0     53488
# 71.0     25857
# Name: count, dtype: int64
#
# Ocupacion de la Mujer:
# Ocupacion de la Mujer
# 97.0    511407
# 23.0     29848
# 52.0     17058
# 41.0     14343
# 97.0     13363
# Name: count, dtype: int64
#
# Departamento de Ocurrencia:
# Departamento de Ocurrencia
# 1.0     165146
# 16.0     62287
# 13.0     58789
# 14.0     54267
# 12.0     53352
# Name: count, dtype: int64
#
# Municipio de Ocurrencia:
# Municipio de Ocurrencia
# 0101    11320
# 0108     3072
# 0115     2669
# 0901     1814
# 0110     1743
# Name: count, dtype: int64
#
# Area Geografica de la Ocurrencia:
# Area Geografica de la Ocurrencia
# 1.0     286747
# 9.0      47813
# 2.0      46066
# 11.0         3
# 3.0          1
# Name: count, dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.gridspec import GridSpec

# Configuración visual
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette("deep")
plt.rcParams['figure.figsize'] = (20, 15)
plt.rcParams['font.size'] = 12

# Crear figura con layout GridSpec para organizar múltiples gráficos
fig = plt.figure(figsize=(20, 20))
gs = GridSpec(3, 2, figure=fig)

# 1. Comparativa de edades en matrimonio vs divorcio
ax1 = fig.add_subplot(gs[0, :])

# Crear dataframe para seaborn con datos reales
edades_mat_h = mat_numeric['Edad del Hombre'].dropna()
edades_mat_m = mat_numeric['Edad de la Mujer'].dropna()
edades_div_h = div_numeric['Edad del Hombre'].dropna()
edades_div_m = div_numeric['Edad de la Mujer'].dropna()

# Muestreo para balancear el tamaño de los datos si es necesario
sample_size = min(len(edades_mat_h), len(edades_mat_m), len(edades_div_h), len(edades_div_m), 5000)

edades_df = pd.DataFrame({
    'Edad': np.concatenate([
        edades_mat_h.sample(sample_size).values, 
        edades_mat_m.sample(sample_size).values, 
        edades_div_h.sample(sample_size).values, 
        edades_div_m.sample(sample_size).values
    ]),
    'Género': ['Hombre']*sample_size + ['Mujer']*sample_size + ['Hombre']*sample_size + ['Mujer']*sample_size,
    'Evento': ['Matrimonio']*sample_size*2 + ['Divorcio']*sample_size*2
})

# Violin plot comparando edades
sns.violinplot(data=edades_df, x='Evento', y='Edad', hue='Género', split=True, inner='quart', ax=ax1)
ax1.set_title('Comparativa de distribución de edades: Matrimonio vs Divorcio', fontsize=16)
ax1.set_ylabel('Edad (años)', fontsize=14)
ax1.set_xlabel('', fontsize=14)
ax1.legend(title='Género')

# 2. Tendencia temporal de divorcios y matrimonios por año
ax2 = fig.add_subplot(gs[1, 0])

# Datos reales agrupados por año
divorcios_por_año = div_numeric['Ano de Registro'].value_counts().sort_index()
years_div = divorcios_por_año.index.tolist()

ax2.plot(years_div, divorcios_por_año.values, 'o-', label='Divorcios', linewidth=3)
ax2.set_title('Tendencia de divorcios por año', fontsize=16)
ax2.set_xlabel('Año', fontsize=14)
ax2.set_ylabel('Número de divorcios', fontsize=14)
ax2.grid(True, linestyle='--', alpha=0.7)

ax3 = fig.add_subplot(gs[1, 1])
matrimonios_por_año = mat_numeric['Ano de Registro'].value_counts().sort_index()
years_mat = matrimonios_por_año.index.tolist()

ax3.plot(years_mat, matrimonios_por_año.values, 'o-', color='green', linewidth=3, label='Matrimonios')
ax3.set_title('Tendencia de matrimonios por año', fontsize=16)
ax3.set_xlabel('Año', fontsize=14)
ax3.set_ylabel('Número de matrimonios', fontsize=14)
ax3.grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
# Análisis adicional: Diferencia de edad entre cónyuges
plt.figure(figsize=(15, 8))

# Calcular diferencia de edad para parejas donde ambos datos están disponibles
div_edades = div_numeric[['Edad del Hombre', 'Edad de la Mujer']].dropna()
mat_edades = mat_numeric[['Edad del Hombre', 'Edad de la Mujer']].dropna()

div_edades['diferencia'] = div_edades['Edad del Hombre'] - div_edades['Edad de la Mujer']
mat_edades['diferencia'] = mat_edades['Edad del Hombre'] - mat_edades['Edad de la Mujer']

plt.subplot(1, 2, 1)
sns.histplot(div_edades['diferencia'], kde=True, color='blue')
plt.axvline(x=div_edades['diferencia'].mean(), color='r', linestyle='--', 
            label=f'Media: {div_edades["diferencia"].mean():.2f} años')
plt.title('Distribución de diferencia de edad entre cónyuges en divorcios', fontsize=14)
plt.xlabel('Diferencia de edad (Hombre - Mujer)', fontsize=12)
plt.legend()

plt.subplot(1, 2, 2)
sns.histplot(mat_edades['diferencia'], kde=True, color='green')
plt.axvline(x=mat_edades['diferencia'].mean(), color='r', linestyle='--', 
            label=f'Media: {mat_edades["diferencia"].mean():.2f} años')
plt.title('Distribución de diferencia de edad entre cónyuges en matrimonios', fontsize=14)
plt.xlabel('Diferencia de edad (Hombre - Mujer)', fontsize=12)
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Características de edad por años de registro (evolución temporal)
plt.figure(figsize=(18, 10))

# Calcular medias de edad por año
div_by_year = div_numeric.groupby('Ano de Registro')[['Edad del Hombre', 'Edad de la Mujer']].mean()
mat_by_year = mat_numeric.groupby('Ano de Registro')[['Edad del Hombre', 'Edad de la Mujer']].mean()

plt.subplot(1, 2, 1)
div_by_year.plot(marker='o', ax=plt.gca())
plt.title('Evolución de la edad media en divorcios por año', fontsize=14)
plt.xlabel('Año de registro', fontsize=12)
plt.ylabel('Edad media (años)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)

plt.subplot(1, 2, 2)
mat_by_year.plot(marker='o', ax=plt.gca())
plt.title('Evolución de la edad media en matrimonios por año', fontsize=14)
plt.xlabel('Año de registro', fontsize=12)
plt.ylabel('Edad media (años)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Correlación entre variables

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(divorcios_df.corr(), annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5, vmin=-1, vmax=1, center=0)
plt.title("Matriz de Correlación - Divorcios")
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(matrimonios_df.corr(), annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5, vmin=-1, vmax=1, center=0)
plt.title("Matriz de Correlación - Matrimonios")
plt.show()

# %% [markdown]
# # Clusters

# %%
divorcios_df = pd.read_csv("divorcios_limpio.csv")

# Reemplazar "IGNORADO" y "NEOG" por NaN en las columnas de ocupación
ocupacion_columns = ['Ocupacion del Hombre', 'Ocupacion de la Mujer']

# Reemplazar valores "IGNORADO" y "NEOG" por NaN
divorcios_df[ocupacion_columns] = divorcios_df[ocupacion_columns].replace(["IGNORADO", "NEOG"], np.nan)
divorcios_df[ocupacion_columns] = divorcios_df[ocupacion_columns].apply(pd.to_numeric, errors='coerce')

# Mostramos los tipos de datos y eliminamos columnas no numéricas
divorcios_num = divorcios_df.select_dtypes(include=[np.number])

# Visualizamos resumen
print(divorcios_num.shape)
divorcios_num.head()
# Out:
# (76669, 19)
# C:\Users\wolfu\AppData\Local\Temp\ipykernel_26508\1696647347.py:1: DtypeWarning: Columns (15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   divorcios_df = pd.read_csv("divorcios_limpio.csv")
#    Departamento de Registro  Municipio de Registro  Mes de Registro  \
# 0                       1.0                    101             12.0
# 1                       1.0                    101              8.0
# 2                      17.0                   1701              8.0
# 3                       1.0                    101              3.0
# 4                      19.0                   1905              2.0
#
#    Ano de Registro  Dia de la Ocurrencia  Mes de la Ocurrencia  \
# 0           2016.0                   3.0                  11.0
# 1           2016.0                  17.0                   5.0
# 2           2016.0                  11.0                   8.0
# 3           2017.0                   7.0                  10.0
# 4           2017.0                  23.0                  11.0
#
#    Ano Ocurrencia  Departamento de Ocurrencia  Municipio de Ocurrencia  \
# 0          2016.0                         1.0                      101
# 1          2016.0                         1.0                      101
# 2          2016.0                         1.0                      101
# 3          2016.0                         1.0                      101
# 4          2016.0                         2.0                      207
#
#    Edad del Hombre  Edad de la Mujer  Nacionalidad del Hombre  \
# 0            999.0             999.0                     32.0
# 1             58.0             999.0                     32.0
# 2             61.0              53.0                     32.0
# 3             39.0              38.0                     40.0
# 4            999.0             999.0                    152.0
#
#    Nacionalidad de la Mujer  Escolaridad del Hombre  Escolaridad de la Mujer  \
# 0                     320.0                     9.0                      9.0
# 1                     320.0                     9.0                      9.0
# 2                     320.0                     0.0                      0.0
# 3                     320.0                     9.0                      4.0
# 4                     320.0                     9.0                      9.0
#
#    Ocupacion del Hombre  Ocupacion de la Mujer  \
# 0                  98.0                   23.0
# 1                  98.0                   98.0
# 2                  99.0                   99.0
# 3                  52.0                   26.0
# 4                  72.0                   98.0
#
#    Pueblo de Pertenencia del Hombre  Pueblo de Pertenencia de la Mujer
# 0                               9.0                                9.0
# 1                               9.0                                9.0
# 2                               9.0                                9.0
# 3                               9.0                                4.0
# 4                               9.0                                9.0

# %%
# Ver resumen estadístico general
print("Edad del Hombre:")
print(divorcios_df["Edad del Hombre"].describe())
print("\nValores únicos más altos:")
print(divorcios_df["Edad del Hombre"].value_counts().sort_index(ascending=False).head(10))

print("\nEdad de la Mujer:")
print(divorcios_df["Edad de la Mujer"].describe())
print("\nValores únicos más altos:")
print(divorcios_df["Edad de la Mujer"].value_counts().sort_index(ascending=False).head(10))
# Out:
# Edad del Hombre:
# count    76669.000000
# mean       470.445356
# std        479.062676
# min         17.000000
# 25%         33.000000
# 50%         51.000000
# 75%        999.000000
# max        999.000000
# Name: Edad del Hombre, dtype: float64
#
# Valores únicos más altos:
# Edad del Hombre
# 999.0    34573
# 98.0         1
# 93.0         1
# 90.0         3
# 88.0         3
# 87.0         2
# 86.0         3
# 85.0         3
# 84.0         4
# 83.0         8
# Name: count, dtype: int64
#
# Edad de la Mujer:
# count    76669.000000
# mean       468.057181
# std        480.558945
# min         15.000000
# 25%         30.000000
# 50%         46.000000
# 75%        999.000000
# max        999.000000
# Name: Edad de la Mujer, dtype: float64
#
# Valores únicos más altos:
# Edad de la Mujer
# 999.0    34521
# 81.0         1
# 80.0         1
# 78.0         4
# 77.0         4
# 76.0         3
# 75.0         6
# 74.0        10
# 73.0         6
# 72.0         9
# Name: count, dtype: int64

# %% [markdown]
# El clustering es sensible a la escala, así que normalizamos los datos:

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

# Reemplazo condicionado por columna
divorcios_num_clean = divorcios_num.copy()

# Columnas donde 9 es considerado como válido
valid_9_columns = ['Departamento de Registro', 'Mes de Registro', 'Dia de la Ocurrencia', 'Mes de la Ocurrencia', 'Departamento de Ocurrencia']
# Columnas donde 9 es considerado como ignorado
ignore_9_columns = ['Pueblo de Pertenencia del Hombre', 'Pueblo de Pertenencia de la Mujer', 'Escolaridad del Hombre', 'Escolaridad de la Mujer']

# Reemplazar 9 por NaN en las columnas donde 9 debe ser ignorado
divorcios_num_clean[ignore_9_columns] = divorcios_num_clean[ignore_9_columns].replace(9, np.nan)

# Reemplazar 9999 por NaN en las columnas donde 9999 debe ser ignorado
divorcios_num_clean['Nacionalidad del Hombre'] = divorcios_num_clean['Nacionalidad del Hombre'].replace(9999, np.nan)
divorcios_num_clean['Nacionalidad de la Mujer'] = divorcios_num_clean['Nacionalidad de la Mujer'].replace(9999, np.nan)

# Reemplazar 999 por NaN en las columnas donde 999 debe ser ignorado
divorcios_num_clean['Edad del Hombre'] = divorcios_num_clean['Edad del Hombre'].replace(999, np.nan)
divorcios_num_clean['Edad de la Mujer'] = divorcios_num_clean['Edad de la Mujer'].replace(999, np.nan)

# Reemplazar 99 por NaN en las columnas donde 99 debe ser ignorado
divorcios_num_clean['Ocupacion del Hombre'] = divorcios_num_clean['Ocupacion del Hombre'].replace(99, np.nan)
divorcios_num_clean['Ocupacion de la Mujer'] = divorcios_num_clean['Ocupacion de la Mujer'].replace(99, np.nan)

# Ahora se puede imputar y escalar
imputer = SimpleImputer(strategy="mean")  
divorcios_imputed = imputer.fit_transform(divorcios_num_clean)

scaler = StandardScaler()
divorcios_scaled = scaler.fit_transform(divorcios_imputed)

# %% [markdown]
# Usamos el método del codo y el coeficiente de silueta:

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

inertia = []
silhouette = []
k_range = range(2, 11)

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(divorcios_scaled)
    inertia.append(kmeans.inertia_)
    silhouette.append(silhouette_score(divorcios_scaled, kmeans.labels_))

# Graficamos ambos
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(k_range, inertia, marker='o')
plt.title("Método del Codo")
plt.xlabel("Número de Clusters")
plt.ylabel("Inercia")

plt.subplot(1,2,2)
plt.plot(k_range, silhouette, marker='o', color='green')
plt.title("Coeficiente de Silueta")
plt.xlabel("Número de Clusters")
plt.ylabel("Score de Silueta")

plt.tight_layout()
plt.show()

# %% [markdown]
# Selecciona el número óptimo:

# %%
optimal_k = 4

kmeans = KMeans(n_clusters=optimal_k, random_state=42)
clusters = kmeans.fit_predict(divorcios_scaled)

# Creamos un nuevo DataFrame a partir de los datos imputados
divorcios_cluster_df = pd.DataFrame(divorcios_imputed, columns=divorcios_num_clean.columns)

# Agregamos los clusters
divorcios_cluster_df["Cluster"] = clusters

# %% [markdown]
# Agrupamos por cluster para observar tendencias:

# %%
cluster_summary = divorcios_cluster_df.groupby("Cluster").mean(numeric_only=True)
cluster_summary.T  # Transpuesta para mejor lectura
# Out:
# Cluster                                      0            1            2  \
# Departamento de Registro              9.903008    15.426100     2.871108
# Municipio de Registro               996.726597  1548.301173   291.543504
# Mes de Registro                       6.423454     6.576082     6.626091
# Ano de Registro                    2019.486651  2018.904103  2017.147528
# Dia de la Ocurrencia                 15.814633    15.683007    15.710469
# Mes de la Ocurrencia                  6.234032     6.307369     6.188193
# Ano Ocurrencia                     2019.879993  2019.629995  2018.258910
# Departamento de Ocurrencia           10.205475    15.678292     3.064408
# Municipio de Ocurrencia            1028.130281  1573.836652   311.607874
# Edad del Hombre                      33.635884    36.272576    35.990077
# Edad de la Mujer                     30.739013    32.849558    32.813402
# Nacionalidad del Hombre             320.281948   321.658320   322.868517
# Nacionalidad de la Mujer            320.696108   322.315558   323.152660
# Escolaridad del Hombre                2.529123     2.788724     2.678329
# Escolaridad de la Mujer               2.434827     2.788447     2.652182
# Ocupacion del Hombre                 73.833834    72.685027    77.227911
# Ocupacion de la Mujer                83.948525    77.831867    82.856585
# Pueblo de Pertenencia del Hombre      1.419870     3.731097     3.655524
# Pueblo de Pertenencia de la Mujer     1.386979     3.775106     3.697580
#
# Cluster                                      3
# Departamento de Registro              3.577962
# Municipio de Registro               361.947796
# Mes de Registro                       6.464056
# Ano de Registro                    2021.069447
# Dia de la Ocurrencia                 15.878402
# Mes de la Ocurrencia                  6.488938
# Ano Ocurrencia                     2021.156003
# Departamento de Ocurrencia            3.827206
# Municipio de Ocurrencia             387.675367
# Edad del Hombre                      37.804577
# Edad de la Mujer                     34.957418
# Nacionalidad del Hombre             325.277791
# Nacionalidad de la Mujer            325.212826
# Escolaridad del Hombre                3.668550
# Escolaridad de la Mujer               3.683400
# Ocupacion del Hombre                 58.515327
# Ocupacion de la Mujer                61.537254
# Pueblo de Pertenencia del Hombre      3.823495
# Pueblo de Pertenencia de la Mujer     3.859598

# %% [markdown]
# También contamos cuántos casos hay por grupo:

# %%
divorcios_cluster_df["Cluster"].value_counts()
# Out:
# Cluster
# 2    26239
# 1    25663
# 3    18849
# 0     5918
# Name: count, dtype: int64

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Reducir a 2 dimensiones para graficar
pca = PCA(n_components=2)
X_reduced = pca.fit_transform(divorcios_scaled)  # datos reducidos

# Proyectar los centroides a 2D también
centroids_2d = pca.transform(kmeans.cluster_centers_)

# Graficar los puntos por cluster
plt.figure(figsize=(10, 7))
colors = ['red', 'blue', 'green', 'purple']

for i in range(optimal_k):
    plt.scatter(X_reduced[clusters == i, 0], X_reduced[clusters == i, 1], 
                s=50, c=colors[i], label=f'Cluster {i}')

# Graficar los centroides
plt.scatter(centroids_2d[:, 0], centroids_2d[:, 1],
            s=300, c='yellow', marker='*', label='Centroides')

# Títulos y etiquetas
plt.title('Clusters de divorcios (PCA)', fontsize=14)
plt.xlabel('Componente Principal 1')
plt.ylabel('Componente Principal 2')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
